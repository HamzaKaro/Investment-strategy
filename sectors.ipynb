# %%
# !pip install datapackage
# Out:
# Collecting datapackage
#   Downloading datapackage-1.15.2-py2.py3-none-any.whl (85 kB)
#      ---------------------------------------- 0.0/85.8 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/85.8 kB ? eta -:--:--
#      --------- ---------------------------- 20.5/85.8 kB 165.2 kB/s eta 0:00:01
#      ------------------ ------------------- 41.0/85.8 kB 281.8 kB/s eta 0:00:01
#      -------------------------------------- 85.8/85.8 kB 439.5 kB/s eta 0:00:00
# Requirement already satisfied: six>=1.10 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from datapackage) (1.16.0)
# Collecting click>=6.7 (from datapackage)
#   Obtaining dependency information for click>=6.7 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting chardet>=3.0 (from datapackage)
#   Obtaining dependency information for chardet>=3.0 from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: requests>=2.8 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from datapackage) (2.31.0)
# Requirement already satisfied: jsonschema>=2.5 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from datapackage) (4.17.3)
# Collecting unicodecsv>=0.14 (from datapackage)
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting jsonpointer>=1.10 (from datapackage)
#   Obtaining dependency information for jsonpointer>=1.10 from https://files.pythonhosted.org/packages/12/f6/0232cc0c617e195f06f810534d00b74d2f348fe71b2118009ad8ad31f878/jsonpointer-2.4-py2.py3-none-any.whl.metadata
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting tableschema>=1.12.1 (from datapackage)
#   Downloading tableschema-1.20.2-py2.py3-none-any.whl (68 kB)
#      ---------------------------------------- 0.0/68.9 kB ? eta -:--:--
#      ---------------------------------------- 68.9/68.9 kB 3.7 MB/s eta 0:00:00
# Collecting tabulator>=1.29 (from datapackage)
#   Downloading tabulator-1.53.5-py2.py3-none-any.whl (72 kB)
#      ---------------------------------------- 0.0/72.1 kB ? eta -:--:--
#      ---------------------------------------- 72.1/72.1 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from click>=6.7->datapackage) (0.4.6)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from jsonschema>=2.5->datapackage) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from jsonschema>=2.5->datapackage) (0.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from requests>=2.8->datapackage) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from requests>=2.8->datapackage) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from requests>=2.8->datapackage) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from requests>=2.8->datapackage) (2023.7.22)
# Collecting cached-property>=1.5 (from tableschema>=1.12.1->datapackage)
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from tableschema>=1.12.1->datapackage) (2.8.2)
# Collecting isodate>=0.5.4 (from tableschema>=1.12.1->datapackage)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#      ---------------------------------------- 41.7/41.7 kB 2.0 MB/s eta 0:00:00
# Collecting rfc3986>=1.1.0 (from tableschema>=1.12.1->datapackage)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting boto3>=1.9 (from tabulator>=1.29->datapackage)
#   Obtaining dependency information for boto3>=1.9 from https://files.pythonhosted.org/packages/17/a4/e161e777d445a5b1029eff4c4272896410d7dac55e17f2889bd9a3517eed/boto3-1.28.78-py3-none-any.whl.metadata
#   Downloading boto3-1.28.78-py3-none-any.whl.metadata (6.7 kB)
# Collecting ijson>=3.0.3 (from tabulator>=1.29->datapackage)
#   Obtaining dependency information for ijson>=3.0.3 from https://files.pythonhosted.org/packages/3f/12/2d9a51a116291589feeeb7c6ab38dfad2a48afe7e22476ce2a0df8e43443/ijson-3.2.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading ijson-3.2.3-cp311-cp311-win_amd64.whl.metadata (21 kB)
# Collecting jsonlines>=1.1 (from tabulator>=1.29->datapackage)
#   Obtaining dependency information for jsonlines>=1.1 from https://files.pythonhosted.org/packages/f8/62/d9ba6323b9202dd2fe166beab8a86d29465c41a0288cbe229fac60c1ab8d/jsonlines-4.0.0-py3-none-any.whl.metadata
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting sqlalchemy>=0.9.6 (from tabulator>=1.29->datapackage)
#   Obtaining dependency information for sqlalchemy>=0.9.6 from https://files.pythonhosted.org/packages/67/e7/7c77fd5290646f929b499992607cf1bc940573098a593080fcc8f7e13a08/SQLAlchemy-2.0.23-cp311-cp311-win_amd64.whl.metadata
#   Downloading SQLAlchemy-2.0.23-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting linear-tsv>=1.0 (from tabulator>=1.29->datapackage)
#   Downloading linear-tsv-1.1.0.tar.gz (9.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting xlrd>=1.0 (from tabulator>=1.29->datapackage)
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#      ---------------------------------------- 96.5/96.5 kB 5.4 MB/s eta 0:00:00
# Collecting openpyxl>=2.6 (from tabulator>=1.29->datapackage)
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      -------------------------------------- 250.0/250.0 kB 7.7 MB/s eta 0:00:00
# Collecting botocore<1.32.0,>=1.31.78 (from boto3>=1.9->tabulator>=1.29->datapackage)
#   Obtaining dependency information for botocore<1.32.0,>=1.31.78 from https://files.pythonhosted.org/packages/64/93/d472917cc8000157d1220f18edf175e06b7f1ac92970e7cdb719d4405b5a/botocore-1.31.78-py3-none-any.whl.metadata
#   Downloading botocore-1.31.78-py3-none-any.whl.metadata (6.1 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.9->tabulator>=1.29->datapackage)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.8.0,>=0.7.0 (from boto3>=1.9->tabulator>=1.29->datapackage)
#   Obtaining dependency information for s3transfer<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/5a/4b/fec9ce18f8874a96c5061422625ba86c3ee1e6587ccd92ff9f5bf7bd91b2/s3transfer-0.7.0-py3-none-any.whl.metadata
#   Downloading s3transfer-0.7.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting et-xmlfile (from openpyxl>=2.6->tabulator>=1.29->datapackage)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from sqlalchemy>=0.9.6->tabulator>=1.29->datapackage) (4.7.1)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=0.9.6->tabulator>=1.29->datapackage)
#   Obtaining dependency information for greenlet!=0.4.17 from https://files.pythonhosted.org/packages/07/e2/91bf652b49f4a7cce91c63e4fe0da518153a52e5f33660f76f971c50ad0e/greenlet-3.0.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading greenlet-3.0.1-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ---------------------------------------- 0.0/199.4 kB ? eta -:--:--
#    --------------------------------------- 199.4/199.4 kB 11.8 MB/s eta 0:00:00
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Downloading boto3-1.28.78-py3-none-any.whl (135 kB)
#    ---------------------------------------- 0.0/135.8 kB ? eta -:--:--
#    ---------------------------------------- 135.8/135.8 kB 8.4 MB/s eta 0:00:00
# Downloading ijson-3.2.3-cp311-cp311-win_amd64.whl (48 kB)
#    ---------------------------------------- 0.0/48.2 kB ? eta -:--:--
#    ---------------------------------------- 48.2/48.2 kB ? eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading SQLAlchemy-2.0.23-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.1 MB 9.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.9/2.1 MB 9.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.1 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------ --- 1.9/2.1 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 9.4 MB/s eta 0:00:00
# Downloading botocore-1.31.78-py3-none-any.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.3 MB 13.8 MB/s eta 0:00:01
#    --- ------------------------------------ 1.0/11.3 MB 12.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.4/11.3 MB 11.2 MB/s eta 0:00:01
#    ------ --------------------------------- 1.9/11.3 MB 11.3 MB/s eta 0:00:01
#    -------- ------------------------------- 2.5/11.3 MB 11.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.0/11.3 MB 11.2 MB/s eta 0:00:01
#    ------------ --------------------------- 3.4/11.3 MB 10.9 MB/s eta 0:00:01
#    -------------- ------------------------- 4.0/11.3 MB 11.1 MB/s eta 0:00:01
#    --------------- ------------------------ 4.5/11.3 MB 10.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.0/11.3 MB 10.7 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.3 MB 10.7 MB/s eta 0:00:01
#    --------------------- ------------------ 6.0/11.3 MB 11.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.5/11.3 MB 11.0 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.3 MB 10.8 MB/s eta 0:00:01
#    -------------------------- ------------- 7.5/11.3 MB 10.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.0/11.3 MB 10.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.3 MB 10.8 MB/s eta 0:00:01
#    ------------------------------- -------- 9.0/11.3 MB 10.6 MB/s eta 0:00:01
#    --------------------------------- ------ 9.3/11.3 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.9/11.3 MB 10.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.4/11.3 MB 10.4 MB/s eta 0:00:01
#    -------------------------------------- - 10.9/11.3 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 9.8 MB/s eta 0:00:00
# Downloading greenlet-3.0.1-cp311-cp311-win_amd64.whl (288 kB)
#    ---------------------------------------- 0.0/288.4 kB ? eta -:--:--
#    --------------------------------------- 288.4/288.4 kB 18.5 MB/s eta 0:00:00
# Downloading s3transfer-0.7.0-py3-none-any.whl (79 kB)
#    ---------------------------------------- 0.0/79.8 kB ? eta -:--:--
#    ---------------------------------------- 79.8/79.8 kB 4.6 MB/s eta 0:00:00
# Building wheels for collected packages: unicodecsv, linear-tsv
#   Building wheel for unicodecsv (setup.py): started
#   Building wheel for unicodecsv (setup.py): finished with status 'done'
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10759 sha256=e4c083075027f58cbadd1632ae07d2a657f5972076853dfa4f2e922da2c35d31
#   Stored in directory: c:\users\hamzp\appdata\local\pip\cache\wheels\ec\03\6f\d2e0162d94c0d451556fa43dd4d5531457245c34a36b41ef4a
#   Building wheel for linear-tsv (setup.py): started
#   Building wheel for linear-tsv (setup.py): finished with status 'done'
#   Created wheel for linear-tsv: filename=linear_tsv-1.1.0-py3-none-any.whl size=7393 sha256=60ba409237dace625b88172335bffdb5a799d1c8782b32395b5f26df57949302
#   Stored in directory: c:\users\hamzp\appdata\local\pip\cache\wheels\8f\b2\76\139aab1aef0729d1fcbc44e8621c208863c9d3a3bcfabaef89
# Successfully built unicodecsv linear-tsv
# Installing collected packages: unicodecsv, ijson, cached-property, xlrd, rfc3986, linear-tsv, jsonpointer, jsonlines, jmespath, isodate, greenlet, et-xmlfile, click, chardet, sqlalchemy, openpyxl, botocore, s3transfer, boto3, tabulator, tableschema, datapackage
# Successfully installed boto3-1.28.78 botocore-1.31.78 cached-property-1.5.2 chardet-5.2.0 click-8.1.7 datapackage-1.15.2 et-xmlfile-1.1.0 greenlet-3.0.1 ijson-3.2.3 isodate-0.6.1 jmespath-1.0.1 jsonlines-4.0.0 jsonpointer-2.4 linear-tsv-1.1.0 openpyxl-3.1.2 rfc3986-2.0.0 s3transfer-0.7.0 sqlalchemy-2.0.23 tableschema-1.20.2 tabulator-1.53.5 unicodecsv-0.14.1 xlrd-2.0.1
# Collecting datapackage
#   Using cached datapackage-1.15.2-py2.py3-none-any.whl (85 kB)
# Requirement already satisfied: six>=1.10 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from datapackage) (1.16.0)
# Collecting click>=6.7 (from datapackage)
#   Obtaining dependency information for click>=6.7 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting chardet>=3.0 (from datapackage)
#   Obtaining dependency information for chardet>=3.0 from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: requests>=2.8 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from datapackage) (2.31.0)
# Requirement already satisfied: jsonschema>=2.5 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from datapackage) (4.17.3)
# Collecting unicodecsv>=0.14 (from datapackage)
#   Using cached unicodecsv-0.14.1.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting jsonpointer>=1.10 (from datapackage)
#   Obtaining dependency information for jsonpointer>=1.10 from https://files.pythonhosted.org/packages/12/f6/0232cc0c617e195f06f810534d00b74d2f348fe71b2118009ad8ad31f878/jsonpointer-2.4-py2.py3-none-any.whl.metadata
#   Using cached jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting tableschema>=1.12.1 (from datapackage)
#   Using cached tableschema-1.20.2-py2.py3-none-any.whl (68 kB)
# Collecting tabulator>=1.29 (from datapackage)
#   Using cached tabulator-1.53.5-py2.py3-none-any.whl (72 kB)
# Requirement already satisfied: colorama in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from click>=6.7->datapackage) (0.4.6)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from jsonschema>=2.5->datapackage) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from jsonschema>=2.5->datapackage) (0.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from requests>=2.8->datapackage) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from requests>=2.8->datapackage) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from requests>=2.8->datapackage) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from requests>=2.8->datapackage) (2023.7.22)
# Collecting cached-property>=1.5 (from tableschema>=1.12.1->datapackage)
#   Using cached cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from tableschema>=1.12.1->datapackage) (2.8.2)
# Collecting isodate>=0.5.4 (from tableschema>=1.12.1->datapackage)
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting rfc3986>=1.1.0 (from tableschema>=1.12.1->datapackage)
#   Using cached rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting boto3>=1.9 (from tabulator>=1.29->datapackage)
#   Obtaining dependency information for boto3>=1.9 from https://files.pythonhosted.org/packages/17/a4/e161e777d445a5b1029eff4c4272896410d7dac55e17f2889bd9a3517eed/boto3-1.28.78-py3-none-any.whl.metadata
#   Using cached boto3-1.28.78-py3-none-any.whl.metadata (6.7 kB)
# Collecting ijson>=3.0.3 (from tabulator>=1.29->datapackage)
#   Obtaining dependency information for ijson>=3.0.3 from https://files.pythonhosted.org/packages/3f/12/2d9a51a116291589feeeb7c6ab38dfad2a48afe7e22476ce2a0df8e43443/ijson-3.2.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached ijson-3.2.3-cp311-cp311-win_amd64.whl.metadata (21 kB)
# Collecting jsonlines>=1.1 (from tabulator>=1.29->datapackage)
#   Obtaining dependency information for jsonlines>=1.1 from https://files.pythonhosted.org/packages/f8/62/d9ba6323b9202dd2fe166beab8a86d29465c41a0288cbe229fac60c1ab8d/jsonlines-4.0.0-py3-none-any.whl.metadata
#   Using cached jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting sqlalchemy>=0.9.6 (from tabulator>=1.29->datapackage)
#   Obtaining dependency information for sqlalchemy>=0.9.6 from https://files.pythonhosted.org/packages/67/e7/7c77fd5290646f929b499992607cf1bc940573098a593080fcc8f7e13a08/SQLAlchemy-2.0.23-cp311-cp311-win_amd64.whl.metadata
#   Using cached SQLAlchemy-2.0.23-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting linear-tsv>=1.0 (from tabulator>=1.29->datapackage)
#   Using cached linear-tsv-1.1.0.tar.gz (9.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting xlrd>=1.0 (from tabulator>=1.29->datapackage)
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Collecting openpyxl>=2.6 (from tabulator>=1.29->datapackage)
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Collecting botocore<1.32.0,>=1.31.78 (from boto3>=1.9->tabulator>=1.29->datapackage)
#   Obtaining dependency information for botocore<1.32.0,>=1.31.78 from https://files.pythonhosted.org/packages/64/93/d472917cc8000157d1220f18edf175e06b7f1ac92970e7cdb719d4405b5a/botocore-1.31.78-py3-none-any.whl.metadata
#   Using cached botocore-1.31.78-py3-none-any.whl.metadata (6.1 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.9->tabulator>=1.29->datapackage)
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.8.0,>=0.7.0 (from boto3>=1.9->tabulator>=1.29->datapackage)
#   Obtaining dependency information for s3transfer<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/5a/4b/fec9ce18f8874a96c5061422625ba86c3ee1e6587ccd92ff9f5bf7bd91b2/s3transfer-0.7.0-py3-none-any.whl.metadata
#   Using cached s3transfer-0.7.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting et-xmlfile (from openpyxl>=2.6->tabulator>=1.29->datapackage)
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\hamzp\miniconda3\envs\desjardins-challenge\lib\site-packages (from sqlalchemy>=0.9.6->tabulator>=1.29->datapackage) (4.7.1)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=0.9.6->tabulator>=1.29->datapackage)
#   Obtaining dependency information for greenlet!=0.4.17 from https://files.pythonhosted.org/packages/07/e2/91bf652b49f4a7cce91c63e4fe0da518153a52e5f33660f76f971c50ad0e/greenlet-3.0.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached greenlet-3.0.1-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Using cached boto3-1.28.78-py3-none-any.whl (135 kB)
# Using cached ijson-3.2.3-cp311-cp311-win_amd64.whl (48 kB)
# Using cached jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Using cached SQLAlchemy-2.0.23-cp311-cp311-win_amd64.whl (2.1 MB)
# Downloading botocore-1.31.78-py3-none-any.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB 660.6 kB/s eta 0:00:18
#    ---------------------------------------- 0.0/11.3 MB 393.8 kB/s eta 0:00:29
#    - -------------------------------------- 0.3/11.3 MB 2.3 MB/s eta 0:00:05
#    -- ------------------------------------- 0.8/11.3 MB 4.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.2/11.3 MB 4.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.4/11.3 MB 5.3 MB/s eta 0:00:02
#    ------ --------------------------------- 1.9/11.3 MB 5.7 MB/s eta 0:00:02
#    -------- ------------------------------- 2.5/11.3 MB 6.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.3 MB 6.9 MB/s eta 0:00:02
#    ------------ --------------------------- 3.5/11.3 MB 7.5 MB/s eta 0:00:02
#    -------------- ------------------------- 4.0/11.3 MB 7.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.6/11.3 MB 8.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.1/11.3 MB 8.3 MB/s eta 0:00:01
#    -------------------- ------------------- 5.7/11.3 MB 8.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/11.3 MB 8.9 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.3 MB 8.9 MB/s eta 0:00:01
#    -------------------------- ------------- 7.4/11.3 MB 9.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.0/11.3 MB 9.3 MB/s eta 0:00:01
#    ------------------------------ --------- 8.6/11.3 MB 9.7 MB/s eta 0:00:01
#    -------------------------------- ------- 9.1/11.3 MB 9.5 MB/s eta 0:00:01
#    --------------------------------- ------ 9.5/11.3 MB 9.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.1/11.3 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------- -- 10.5/11.3 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.3 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 10.1 MB/s eta 0:00:00
# Using cached greenlet-3.0.1-cp311-cp311-win_amd64.whl (288 kB)
# Using cached s3transfer-0.7.0-py3-none-any.whl (79 kB)
# Building wheels for collected packages: unicodecsv, linear-tsv
#   Building wheel for unicodecsv (setup.py): started
#   Building wheel for unicodecsv (setup.py): finished with status 'done'
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10759 sha256=5efef1e9652cae49c9e440685e4427aca3359b09e11ab396df110c9920f236e4
#   Stored in directory: c:\users\hamzp\appdata\local\pip\cache\wheels\ec\03\6f\d2e0162d94c0d451556fa43dd4d5531457245c34a36b41ef4a
#   Building wheel for linear-tsv (setup.py): started
#   Building wheel for linear-tsv (setup.py): finished with status 'done'
#   Created wheel for linear-tsv: filename=linear_tsv-1.1.0-py3-none-any.whl size=7393 sha256=60ba409237dace625b88172335bffdb5a799d1c8782b32395b5f26df57949302
#   Stored in directory: c:\users\hamzp\appdata\local\pip\cache\wheels\8f\b2\76\139aab1aef0729d1fcbc44e8621c208863c9d3a3bcfabaef89
# Successfully built unicodecsv linear-tsv
# Installing collected packages: unicodecsv, ijson, cached-property, xlrd, rfc3986, linear-tsv, jsonpointer, jsonlines, jmespath, isodate, greenlet, et-xmlfile, click, chardet, sqlalchemy, openpyxl, botocore, s3transfer, boto3, tabulator, tableschema, datapackage
# Successfully installed boto3-1.28.78 botocore-1.31.78 cached-property-1.5.2 chardet-5.2.0 click-8.1.7 datapackage-1.15.2 et-xmlfile-1.1.0 greenlet-3.0.1 ijson-3.2.3 isodate-0.6.1 jmespath-1.0.1 jsonlines-4.0.0 jsonpointer-2.4 linear-tsv-1.1.0 openpyxl-3.1.2 rfc3986-2.0.0 s3transfer-0.7.0 sqlalchemy-2.0.23 tableschema-1.20.2 tabulator-1.53.5 unicodecsv-0.14.1 xlrd-2.0.1

# %%
import datapackage
import pandas as pd

data_url = 'https://datahub.io/core/s-and-p-500-companies/datapackage.json'

# to load Data Package into storage
package = datapackage.Package(data_url)

# to load only tabular data
resources = package.resources
for resource in resources:
    if resource.tabular:
        data = pd.read_csv(resource.descriptor['path'])
        print (data)
# Out:
#     Symbol                 Name                  Sector
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4     ABMD              Abiomed             Health Care
# ..     ...                  ...                     ...
# 500    YUM          Yum! Brands  Consumer Discretionary
# 501   ZBRA   Zebra Technologies  Information Technology
# 502    ZBH        Zimmer Biomet             Health Care
# 503   ZION        Zions Bancorp              Financials
# 504    ZTS               Zoetis             Health Care
#
# [505 rows x 3 columns]
#     Symbol                 Name                  Sector
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4     ABMD              Abiomed             Health Care
# ..     ...                  ...                     ...
# 500    YUM          Yum! Brands  Consumer Discretionary
# 501   ZBRA   Zebra Technologies  Information Technology
# 502    ZBH        Zimmer Biomet             Health Care
# 503   ZION        Zions Bancorp              Financials
# 504    ZTS               Zoetis             Health Care
#
# [505 rows x 3 columns]

# %%
# sectors file path
file_path = './additional_data/SP500_symbol_info.csv'

# Read sectors file
sectors_file = pd.read_csv(file_path)
my_dict = {}
for index, row in sectors_file.iterrows():
    key = row['GICS Sector']
    value = row['Symbol']
    if key in my_dict:
        my_dict[key].append(value)
    else:
        my_dict[key] = [value]
# sectors = dict(zip(sectors_file['Symbol'], sectors_file['GICS Sector']))

# %%
my_dict
# Out:
# {'Industrials': ['MMM',
#   'ADP',
#   'BA',
#   'CHRW',
#   'CAT',
#   'CTAS',
#   'CSX',
#   'CMI',
#   'DE',
#   'DOV',
#   'ETN',
#   'EMR',
#   'EFX',
#   'EXPD',
#   'FAST',
#   'FDX',
#   'GD',
#   'GE',
#   'HON',
#   'HWM',
#   'ITW',
#   'J',
#   'JCI',
#   'LHX',
#   'LMT',
#   'MAS',
#   'NSC',
#   'NOC',
#   'PCAR',
#   'PH',
#   'PAYX',
#   'PWR',
#   'RTX',
#   'RSG',
#   'RHI',
#   'SNA',
#   'LUV',
#   'SWK',
#   'TXT',
#   'TT',
#   'UNP',
#   'UPS',
#   'GWW',
#   'XYL'],
#  'Health Care': ['ABT',
#   'A',
#   'AMGN',
#   'BAX',
#   'BDX',
#   'BIIB',
#   'BSX',
#   'BMY',
#   'CAH',
#   'COR',
#   'CI',
#   'CVS',
#   'DHR',
#   'DVA',
#   'XRAY',
#   'EW',
#   'ELV',
#   'LLY',
#   'GILD',
#   'ISRG',
#   'JNJ',
#   'LH',
#   'MCK',
#   'MDT',
#   'MRK',
#   'PFE',
#   'DGX',
#   'RVTY',
#   'SYK',
#   'TMO',
#   'UNH',
#   'VTRS',
#   'WAT',
#   'ZBH'],
#  'Information Technology': ['ACN',
#   'ADBE',
#   'AKAM',
#   'APH',
#   'ADI',
#   'AAPL',
#   'AMAT',
#   'ADSK',
#   'CSCO',
#   'CTSH',
#   'GLW',
#   'FFIV',
#   'GEN',
#   'HPQ',
#   'IBM',
#   'INTC',
#   'INTU',
#   'JNPR',
#   'KLAC',
#   'MCHP',
#   'MU',
#   'MSFT',
#   'MSI',
#   'NTAP',
#   'NVDA',
#   'ORCL',
#   'QCOM',
#   'ROP',
#   'CRM',
#   'TEL',
#   'VRSN',
#   'WDC'],
#  'Consumer Staples': ['ADM',
#   'MO',
#   'BF.B',
#   'CPB',
#   'CLX',
#   'KO',
#   'CL',
#   'CAG',
#   'STZ',
#   'COST',
#   'DLTR',
#   'EL',
#   'GIS',
#   'HSY',
#   'HRL',
#   'K',
#   'KMB',
#   'KR',
#   'MKC',
#   'TAP',
#   'PEP',
#   'PM',
#   'PG',
#   'SJM',
#   'SYY',
#   'TGT',
#   'TSN',
#   'WBA',
#   'WMT'],
#  'Utilities': ['AES',
#   'AEE',
#   'AEP',
#   'CNP',
#   'CMS',
#   'ED',
#   'DTE',
#   'DUK',
#   'EIX',
#   'ETR',
#   'ES',
#   'EXC',
#   'FE',
#   'NEE',
#   'NI',
#   'NRG',
#   'PNW',
#   'PPL',
#   'PEG',
#   'SRE',
#   'SO',
#   'WEC',
#   'XEL'],
#  'Financials': ['AFL',
#   'ALL',
#   'AXP',
#   'AIG',
#   'AMP',
#   'AON',
#   'AIZ',
#   'BAC',
#   'BRK.B',
#   'BLK',
#   'BK',
#   'COF',
#   'SCHW',
#   'CB',
#   'CINF',
#   'C',
#   'CME',
#   'CMA',
#   'DFS',
#   'FITB',
#   'FIS',
#   'FI',
#   'BEN',
#   'GL',
#   'GS',
#   'HIG',
#   'HBAN',
#   'ICE',
#   'IVZ',
#   'JPM',
#   'KEY',
#   'L',
#   'MTB',
#   'MMC',
#   'MA',
#   'MET',
#   'MCO',
#   'MS',
#   'NDAQ',
#   'NTRS',
#   'PNC',
#   'PFG',
#   'PGR',
#   'PRU',
#   'RF',
#   'SPGI',
#   'STT',
#   'TRV',
#   'TFC',
#   'V',
#   'WFC',
#   'ZION'],
#  'Materials': ['APD',
#   'AVY',
#   'BALL',
#   'CF',
#   'EMN',
#   'ECL',
#   'FMC',
#   'IFF',
#   'IP',
#   'LIN',
#   'MOS',
#   'NEM',
#   'NUE',
#   'PPG',
#   'SEE',
#   'SHW',
#   'VMC',
#   'WRK'],
#  'Communication Services': ['GOOG',
#   'T',
#   'CMCSA',
#   'DIS',
#   'EA',
#   'IPG',
#   'NFLX',
#   'OMC',
#   'PARA',
#   'VZ'],
#  'Consumer Discretionary': ['AMZN',
#   'AZO',
#   'BBWI',
#   'BBY',
#   'BKNG',
#   'BWA',
#   'KMX',
#   'CCL',
#   'CMG',
#   'DHI',
#   'DRI',
#   'EBAY',
#   'EXPE',
#   'F',
#   'GPC',
#   'HAS',
#   'HD',
#   'LEN',
#   'LOW',
#   'MAR',
#   'MCD',
#   'NKE',
#   'ORLY',
#   'PHM',
#   'RL',
#   'ROST',
#   'SBUX',
#   'TPR',
#   'TJX',
#   'VFC',
#   'WYNN',
#   'YUM'],
#  'Real Estate': ['AMT',
#   'AVB',
#   'BXP',
#   'CBRE',
#   'EQR',
#   'PEAK',
#   'HST',
#   'IRM',
#   'KIM',
#   'PLD',
#   'PSA',
#   'SPG',
#   'VTR',
#   'WELL'],
#  'Energy': ['APA',
#   'CVX',
#   'COP',
#   'CTRA',
#   'DVN',
#   'EOG',
#   'XOM',
#   'HAL',
#   'HES',
#   'MRO',
#   'MPC',
#   'OXY',
#   'OKE',
#   'PXD',
#   'SLB',
#   'VLO',
#   'WMB']}
